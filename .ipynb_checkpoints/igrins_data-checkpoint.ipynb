# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob

from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)


from astropy.io import ascii
from astropy.io import fits
from astropy.table import Table, Column, join
from astropy.wcs import WCS

# %%
data_path = 'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged/'
hops368_file = data_path+'mHOPS368_20180115_K_0059_spec_A0v.fits'

# %%
merged_files = glob.glob(data_path+'m*.fits')
merged_files
# Out:
# ['A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS368_20180115_K_0059_spec_A0v.fits',
#  'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS369_20180117_K_0053_spec_A0v.fits',
#  'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS370South_20190123_K_0075_spec_A0v.fits',
#  'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS370_20190123_K_0071_spec_A0v.fits',
#  'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS386_20171228_K_0083_spec_A0v.fits',
#  'A:/Documents/Grad_School/IGRINS-Spectra/IGRINS_Merged\\mHOPS388_20181120_K_0091.fits']

# %%
# data_stack = np.zeros(44573,len(merged_files))
# wavlen_stack = np.zeros(44573,len(merged_files))
# flux_stack = np.zeros(44573,len(merged_files))
# # Create a stack of arrays with the wavelengths and fluxes
# for i in range(len(merged_files)):
    
#     data_stack = fits.getdata(merged_files[i])
#     wavlen_stack = data_stack.data[0]
#     flux_stack = data_stack.data[1]

# %%
hops368_data = fits.getdata(merged_files[0])
hops368_hdr = fits.getheader(merged_files[0])

hops369_data = fits.getdata(merged_files[1])
hops369_hdr = fits.getheader(merged_files[1])

hops370s_data = fits.getdata(merged_files[2])
hops370s_hdr = fits.getheader(merged_files[2])

hops370_data = fits.getdata(merged_files[3])
hops370_hdr = fits.getheader(merged_files[3])

hops386_data = fits.getdata(merged_files[4])
hops386_hdr = fits.getheader(merged_files[4])

hops388_data = fits.getdata(merged_files[5])
hops388_hdr = fits.getheader(merged_files[5])

# %%
# Wavelength (micron)
hops368_wavlen = hops368_data[0]
hops369_wavlen = hops369_data[0]
hops370s_wavlen = hops370s_data[0]
hops370_wavlen = hops370_data[0]
hops386_wavlen = hops386_data[0]
hops388_wavlen = hops388_data[0]

# Flux (Counts)
hops368_flux = hops368_data[1]
hops369_flux = hops369_data[1]
hops370s_flux = hops370s_data[1]
hops370_flux = hops370_data[1]
hops386_flux = hops386_data[1]
hops388_flux = hops388_data[1]

# %%
# hops368_hdr

# %%
# NIR Lines
nir_dict = {
    "Fe-2.084": 2.084,
    "Si-2.092"	:	2.092,
    "Mg-2.106"	:	2.106,
    "Al-2.11"	:	2.11,
    "Ca-2.2035"	:	2.2035,
    "Fe-2.2037"	:	2.2037,
    "Sc-2.2052"	:	2.2052,
    "Na-2.2052"	:	2.2052,
    "Si-2.2063"	:	2.2063,
    "Sc-2.2065"	:	2.2065,
    "Si-2.2073"	:	2.2073,
    "Fe-2.2079"	:	2.2079,
    "Na-2.2083"	:	2.2083,
    "Ca-2.2113"	:	2.2113,
    "Ti-2.2218"	:	2.2218,
    "Ti-2.224"	:	2.224,
    "Fe-2.226"	:	2.226,
    "Ti-2.228"	:	2.228,
    "Ti-2.232"	:	2.232,
    "Ca-2.26573"	:	2.26573,
    "Fe-2.2742"	:	2.2742,
    "Mg-2.281"	:	2.281,
    "Ca-2.2825"	:	2.2825,
    "Fe-2.284"	:	2.284,
    "Ti-2.29"	:	2.29,
    "Ti-2.297"	:	2.297,
    "CO(2-0)-2.29353" :	2.29353,
    "CO(2-0)-2.32265"	:	2.32265,
    "CO(2-0)-2.34327" :	2.34327,
    "CO(2-0)-2.34531" :	2.34531,
    "CO(2-0)-2.3495" 	:	2.3495,
    "CO(2-0)-2.35167"	:	2.35167,
    "CO(2-0)-2.35246" :	2.35246,
    "CO(2-0)-2.38295" :	2.38295,
}

# %%
# Strings of the Nir lines
lines_str = list(nir_dict.keys())

# Wavelength values for each NIR line
lines_wav = list(nir_dict.values())

# %%
nir_dict["Fe-2.084"]
# Out:
# 2.084

# %%
n = len(merged_files)
fig, axs = plt.subplots(n,1,sharey=True,figsize=(20,10))

# Plot wavelength vs flux for 6 HOPS sources
# there is definitely a way to do this with a loop but oh well
axs[0].plot(hops368_wavlen, hops368_flux)
axs[1].plot(hops369_wavlen,hops369_flux)
axs[2].plot(hops370s_wavlen,hops370s_flux)
axs[3].plot(hops370_wavlen,hops370_flux)
axs[4].plot(hops386_wavlen,hops386_flux)
axs[5].plot(hops388_wavlen,hops388_flux)

# loop so I can just add all the NIR lines at once
for i in range(n):
    for ii in range(len(nir_wavlen)):
        axs[i].axvline(x=nir_wavlen[ii],ls='dashed',color='black',alpha=0.7)
    axs[i].set_xscale('log')
    axs[i].set_yscale('log')

# Labels
# add an invisble 'frame' to go on top to make axis labels easy
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)

plt.xlabel('Wavelength ($\mu m$)',fontsize=16)
plt.ylabel('Flux (counts)',fontsize=16)
plt.title()

plt.savefig("Merged_HOPS_Spectra_loglog" + '.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-79bf6d317830> in <module>
#      13 # loop so I can just add all the NIR lines at once
#      14 for i in range(n):
# ---> 15     for ii in range(len(nir_wavlen)):
#      16         axs[i].axvline(x=nir_wavlen[ii],ls='dashed',color='black',alpha=0.7)
#      17     axs[i].set_xscale('log')
#
# NameError: name 'nir_wavlen' is not defined

# %%
n = len(merged_files)
# fig, axs = plt.subplots(n,1,sharey=True,figsize=(20,10))
fig,ax = plt.subplots(figsize=(20,10))

# Plot wavelength vs flux for 6 HOPS sources
# there is definitely a way to do this with a loop but oh well
plt.plot(hops368_wavlen, hops368_flux,label="HOPS368")
plt.plot(hops369_wavlen,hops369_flux,label="HOPS369")
plt.plot(hops370s_wavlen,hops370s_flux,label="HOPS370S")
plt.plot(hops370_wavlen,hops370_flux,label="HOPS370")
plt.plot(hops386_wavlen,hops386_flux,label="HOPS386")
plt.plot(hops388_wavlen,hops388_flux,label="HOPS388")

# loop so I can just add all the NIR lines at once
# for i in range(n):
for ii in range(len(nir_wavlen)):
    ax.axvline(x=nir_wavlen[ii],ls='dashed',color='black',alpha=0.7)
    ax.set_xscale('log')
    ax.set_yscale('log')

plt.legend(loc='best')

# Labels
# add an invisble 'frame' to go on top to make axis labels easy
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.title("IGRINS Spectra", fontsize = 22)
plt.xlabel('Wavelength ($\mu m$)',fontsize=16)
plt.ylabel('Flux (counts)',fontsize=16)


# plt.savefig("Merged_HOPS_Spectra_loglog" + '.png')
plt.show()

# %%
# This will be for looking at individual lines maybe?
n = len(merged_files)
# fig, axs = plt.subplots(n,1,sharey=True,figsize=(20,10))
fig,ax = plt.subplots(figsize=(20,10))

# Plot wavelength vs flux for 6 HOPS sources
# there is definitely a way to do this with a loop but oh well
plt.plot(hops368_wavlen, hops368_flux,label="HOPS368")
plt.plot(hops369_wavlen,hops369_flux,label="HOPS369")
plt.plot(hops370s_wavlen,hops370s_flux,label="HOPS370S")
plt.plot(hops370_wavlen,hops370_flux,label="HOPS370")
plt.plot(hops386_wavlen,hops386_flux,label="HOPS386")
plt.plot(hops388_wavlen,hops388_flux,label="HOPS388")

# Fe-2.084
plt.xlim(nir_dict["Fe-2.084"]-1e-3,nir_dict["Fe-2.084"]+1e-3)

# loop so I can just add all the NIR lines through the subplots
# for i in range(n):
for ii in range(len(nir_wavlen)):
    ax.axvline(x=nir_wavlen[ii],ls='dashed',color='black',alpha=0.7)
    ax.set_xscale('log')
    ax.set_yscale('log')

plt.legend(loc='best')

# Labels
# add an invisble 'frame' to go on top to make axis labels easy
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.title("IGRINS Spectra", fontsize = 22)
plt.xlabel('Wavelength ($\mu m$)',fontsize=16)
plt.ylabel('Flux (counts)',fontsize=16)


# plt.savefig("Merged_HOPS_Spectra_loglog" + '.png')
plt.show()

# %%
# This will be for looking at individual lines maybe?
n = len(merged_files)
# fig, axs = plt.subplots(n,1,sharey=True,figsize=(20,10))

for k in nir_dict:
    fig,ax = plt.subplots(figsize=(20,10))
    # Plot wavelength vs flux for 6 HOPS sources
    # there is definitely a way to do this with a loop but oh well
    plt.plot(hops368_wavlen, hops368_flux,label="HOPS368")
    plt.plot(hops369_wavlen,hops369_flux,label="HOPS369")
    plt.plot(hops370s_wavlen,hops370s_flux,label="HOPS370S")
    plt.plot(hops370_wavlen,hops370_flux,label="HOPS370")
    plt.plot(hops386_wavlen,hops386_flux,label="HOPS386")
    plt.plot(hops388_wavlen,hops388_flux,label="HOPS388")

    # "Si-2.092"
    plt.xlim(nir_dict[k]-1e-3,nir_dict[k]+1e-3)

    # loop so I can just add all the NIR lines through the subplots
    # for i in range(n):
    for ii in range(len(nir_wavlen)):
        ax.axvline(x=nir_wavlen[ii],ls='dashed',color='black',alpha=0.7)
        ax.set_xscale('log')
        ax.set_yscale('log')

    plt.legend(loc='best')

    # Labels
    # add an invisble 'frame' to go on top to make axis labels easy
    fig.add_subplot(111, frameon=False)
    plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
    plt.title("IGRINS Spectra", fontsize = 22)
    plt.xlabel('Wavelength ($\mu m$)',fontsize=16)
    plt.ylabel('Flux (counts)',fontsize=16)


    # plt.savefig("Merged_HOPS_Spectra_loglog" + '.png')
    plt.show()
